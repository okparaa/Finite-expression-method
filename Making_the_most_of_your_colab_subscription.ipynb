# %% [markdown]
# <a href="https://colab.research.google.com/github/okparaa/Finite-expression-method/blob/main/Making_the_most_of_your_colab_subscription.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/okparaa/Finite-expression-method.git
# Out:
# Cloning into 'Finite-expression-method'...
# remote: Enumerating objects: 114, done.
# remote: Counting objects: 100% (114/114), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 114 (delta 49), reused 57 (delta 16), pack-reused 0
# Receiving objects: 100% (114/114), 487.55 KiB | 15.24 MiB/s, done.
# Resolving deltas: 100% (49/49), done.

# %%
cd /content/Finite-expression-method/fex/Schrodinger
# Out:
# /content/Finite-expression-method/fex/Schrodinger

# %%
! python controller_cubic_sh_firstdeflation_thenintegral.py --epoch 1000 --bs 10 --greedy 0.1 --gpu 0 --ckpt 'Firstdeflat_thenintegral_epoch1k_Dim6' --tree depth2_sub --random_step 3 --lr 0.002 --dim 6 --base 200000 --left -1 --right 1  --domainbs 2000 --intbs 10000
# Out:
# Streaming output truncated to the last 5000 lines.
# ---------------------------------- batch idx 3 -------------------------------------
# ---------------------------------- batch idx 4 -------------------------------------
# ---------------------------------- batch idx 5 -------------------------------------
# ---------------------------------- batch idx 6 -------------------------------------
# ---------------------------------- batch idx 7 -------------------------------------
# ---------------------------------- batch idx 8 -------------------------------------
# ---------------------------------- batch idx 9 -------------------------------------
# ---------------------------------- step 546 -------------------------------------
# ---------------------------------- batch idx 0 -------------------------------------
# ---------------------------------- batch idx 1 -------------------------------------
# ...
